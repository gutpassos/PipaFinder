# %% [markdown]
# # <font color='blue'>Deep Learning II</font>

# %% [markdown]
# # Redes Neurais Recorrentes LSTM - Long Short-Term Memory

# %% [markdown]
# Este Notebook está dividido nas seguintes etapas. Clique no título da etapa para acessá-la diretamente.
#
# * [Etapa 1](#etapa1): Conjunto de dados
# * [Etapa 2](#etapa2): Importar as Bibliotecas
# * [Etapa 3](#etapa3): Criar o Modelo
# * [Etapa 4](#etapa4): Testar o Modelo
# * [Etapa 5](#etapa5): Realizar as Previsões

# %% [markdown]
# # Prevendo Séries Temporais com Stacked LSTMs

# %% [markdown]
# Finalmente, vejamos um dos maiores benefícios das LSTMs, o fato de que elas podem ser treinadas com sucesso quando empilhadas em arquiteturas de redes profundas. As redes LSTM podem ser empilhadas em Keras da mesma maneira que outros tipos de camada podem ser empilhadas. Uma adição é que a camada LSTM anterior a cada camada LSTM subsequente, deve retornar a sequência. Isso pode ser feito configurando o parâmetro return_sequences = True na camada 1.

# %% [markdown]
# <a id = 'etapa1'></a>
# ## Etapa 1: Conjunto de dados

# %% [markdown]
# Previsão de Capacidade do Mainframe - Consumo dos Jobs do Broker

# %% [markdown]
# Usaremos conjuntos de dados que mostram o Consumo dos Jobs do Broker.

# %% [markdown]
# <a id='etapa2'></a>
# ## Etapa 2: Importar as Bibliotecas

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.5.0'

# %%
import keras as k
k.__version__
# Out:
# '2.5.0'

# %%
# Imports
import math
import numpy
import pandas as pd
import os
import io
import requests

from pandas.tseries.offsets import DateOffset

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from keras.models import load_model

# Imports para visualização de dados
import matplotlib.pyplot as plt
import matplotlib as m

# Imports para formatação dos gráficos
plt.style.use('fivethirtyeight')
m.rcParams['axes.labelsize'] = 14
m.rcParams['xtick.labelsize'] = 12
m.rcParams['ytick.labelsize'] = 12
m.rcParams['text.color'] = 'k'
from pylab import rcParams
rcParams['figure.figsize'] = 20, 10

from time import time
from datetime import datetime

# %%
# Função Converte array em matriz
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return numpy.array(dataX), numpy.array(dataY)

# %%
# Função Carrega os dados
def carrega_dados():

    # Carrega os dataframe
    dataframe = pd.read_csv("./CSV/pipaColBrokerDia.csv")
    dataframe['DATA'] = pd.to_datetime(dataframe.DATA, format = '%Y-%m-%dT%H:%M:%S.%fZ')
    dataframe.rename(columns={'DATA': 'Data'}, inplace=True)
    dataframe = dataframe[['Data','BROKER','SERVICE_NAME','SERVICE_CLASS','PROGRAMA', 'QUANTIDADE']]
    dataframe.rename(columns={'BROKER': 'Broker', 'SERVICE_NAME': 'Service_name', 'SERVICE_CLASS': 'Service_class',
                          'PROGRAMA': 'Programa', 'QUANTIDADE': 'Quantidade'}, inplace=True)

    # Carregando os dados
    # Podemos carregar este conjunto de dados facilmente usando a biblioteca Pandas. Não estamos interessados na data,
    # pois que cada observação é separada pelo mesmo intervalo de um mês. Portanto, quando
    # carregamos o conjunto de dados, podemos excluir a primeira coluna. O conjunto de dados baixado também tem rodapé
    # com informações que podemos excluir com o argumento skipfooter para pandas.read_csv() 
    # Uma vez carregado, podemos plotar facilmente todo o conjunto de dados. 

    datasetfull = dataframe.copy()

    filtro1 = datasetfull['Broker']=='ETB170'
    filtro2 = datasetfull['Service_name']=='PORTALDETRAN'
    filtro3 = datasetfull['Programa']=='NSDGX500'
    datasetfull = datasetfull[filtro1 & filtro2 & filtro3]

    datasetfull = datasetfull.rename_axis('index').reset_index()
    datasetfull.drop(columns=['index','Broker','Service_name','Service_class','Programa'], inplace=True)

    # Remove as linhas com as datas duplicadas
    # Vamos transformar a coluna de data no índice do conjunto de dados. Isso vai facilitar nosso trabalho mais a frente.
    # inclui dados missing com a interpolação 

    datasetfull.drop_duplicates(subset='Data', inplace=True)
    datasetfull = datasetfull.set_index('Data')
    datasetfull = datasetfull.resample('D').interpolate()

    datasetfull = datasetfull.values
    datasetfull = datasetfull.astype('float32')

    return datasetfull

# %%
# Função Split em treino e teste
def split_train_test(datasetfull):
    train_size = int(len(datasetfull) * 0.75)
    test_size = len(datasetfull) - train_size
    dataset, test = datasetfull[0:train_size,:], datasetfull[train_size:len(datasetfull),:]
    return dataset, test

# %%
# Função Split em treino e validação
def split_train_test_valid(train_set):
    train_size = int(len(dataset) * 0.67)
    valid_size = len(dataset) - train_size
    train, valid = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
    return train, valid

# %%
# Define o PATH onde estão os dados
save_path = "./save"

# Random seed 
numpy.random.seed(7)

look_back = 10

# Cria o objeto scaler no intervalo [0, 1]
# usando a classe MinMaxScaler do scikit-learn
scaler = MinMaxScaler(feature_range = (0, 1))

# %% [markdown]
# Clique no título da etapa para acessá-la diretamente.
#
# * [Etapa 1](#etapa1): Conjunto de dados
# * [Etapa 2](#etapa2): Importar as Bibliotecas
# * [Etapa 3](#etapa3): Criar o Modelo
# * [Etapa 4](#etapa4): Testar o Modelo
# * [Etapa 5](#etapa5): Realizar as Previsões

# %%
# Carrega os dados
datasetfull = carrega_dados()

# %%
# Split em treino e teste
dataset, test = split_train_test(datasetfull)

# %%
# Função Normaliza os dados
# As LSTMs são sensíveis à escala dos dados de entrada, especificamente quando funções de ativação sigmoide (padrão)
# ou tanh são usadas. Pode ser uma boa prática redimensionar os dados para o range de 0 a 1, 
# também chamado de normalização. 

dataset = scaler.fit_transform(dataset)

# %%
# Split em treino e validação
train, valid = split_train_test_valid(dataset)

# %%
dataset.shape
# Out:
# (273, 1)

# %%
train.shape
# Out:
# (182, 1)

# %%
valid.shape
# Out:
# (91, 1)

# %%
test.shape
# Out:
# (92, 1)

# %%
# Reshape em X=t e Y=t+1
trainX, trainY = create_dataset(train, look_back)
validX, validY = create_dataset(valid, look_back)

# Reshape do input para: [samples, time steps, features]
# Time steps
trainX = numpy.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
validX = numpy.reshape(validX, (validX.shape[0], validX.shape[1], 1))

# %%
# Cria o modelo LSTM
batch_size = 1

model = Sequential()
model.add(LSTM(100, batch_input_shape = (batch_size, look_back, 1), activation = 'tanh', return_sequences = True))
model.add(LSTM(50, activation = 'tanh', return_sequences = True))
model.add(LSTM(20,  activation = 'tanh'))
model.add(Dense(10, activation = 'tanh'))
model.add(Dense(5, activation = 'tanh'))
model.add(Dense(1))
    
model.compile(loss = 'mean_squared_error', optimizer = 'adam')

# %%
# Cria o modelo LSTM
batch_size = 1

model = Sequential()
model.add(LSTM(200, batch_input_shape = (batch_size, look_back, 1), activation = 'tanh', return_sequences = True))
model.add(LSTM(100, activation = 'tanh', return_sequences = True))
model.add(LSTM(50,  activation = 'tanh', return_sequences = True))
model.add(LSTM(25,  activation = 'tanh'))
model.add(Dense(20, activation = 'tanh'))
model.add(Dense(10, activation = 'tanh'))
model.add(Dense(1))
    
model.compile(loss = 'mean_squared_error', optimizer = 'adam')

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_15 (LSTM)               (1, 10, 100)              40800
# _________________________________________________________________
# lstm_16 (LSTM)               (1, 10, 50)               30200
# _________________________________________________________________
# lstm_17 (LSTM)               (1, 20)                   5680
# _________________________________________________________________
# dense_12 (Dense)             (1, 10)                   210
# _________________________________________________________________
# dense_13 (Dense)             (1, 5)                    55
# _________________________________________________________________
# dense_14 (Dense)             (1, 1)                    6
# =================================================================
# Total params: 76,951
# Trainable params: 76,951
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_8 (LSTM)                (1, 10, 200)              161600
# _________________________________________________________________
# lstm_9 (LSTM)                (1, 10, 100)              120400
# _________________________________________________________________
# lstm_10 (LSTM)               (1, 10, 50)               30200
# _________________________________________________________________
# lstm_11 (LSTM)               (1, 25)                   7600
# _________________________________________________________________
# dense_6 (Dense)              (1, 20)                   520
# _________________________________________________________________
# dense_7 (Dense)              (1, 10)                   210
# _________________________________________________________________
# dense_8 (Dense)              (1, 1)                    11
# =================================================================
# Total params: 320,541
# Trainable params: 320,541
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Treinamento
start = time()
current_time = datetime.now().strftime("%H:%M:%S")
print("Hora de Início =", current_time)

for i in range(300):
    model.fit(trainX, trainY, epochs = 1, batch_size = batch_size, verbose = 1, shuffle = False)
    model.reset_states()
    
current_time = datetime.now().strftime("%H:%M:%S")
print("\nHora de Término =", current_time)    
print ('Tempo gasto: %s segundos' % str(time() - start))
# Out:
# Hora de Início = 23:52:11
# 171/171 [==============================] - 8s 12ms/step - loss: 0.0499
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0382
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0378
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0376
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0374
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0372
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0372
# 171/171 [==============================] - 2s 13ms/step - loss: 0.0371
# 171/171 [==============================] - 2s 13ms/step - loss: 0.0370
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0371:
# 171/171 [==============================] - 2s 13ms/step - loss: 0.0368
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0368
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0371
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0366
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0364
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0364
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0360
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0357
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0351
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0349
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0345
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0341
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0337
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0334
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0331
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0328
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0331
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0326
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0324
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0319
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0322
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0315
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0314
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0323
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0309
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0311
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0317
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0298
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0300
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0279
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0320
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0304
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0288
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0284
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0288
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0293
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0294
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0289
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0297
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0280
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0276
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0269
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0285
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0273
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0260
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0267
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0260
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0243
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0256
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0226
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0224
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0212
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0203
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0191
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0238
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0192
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0192
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0176
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0168
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0133
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0129
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0113
# 171/171 [==============================] - 2s 13ms/step - loss: 0.0185
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0138
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0136
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0118
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0084
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0087
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0071
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0068
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0072
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0071
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0076
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0095
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0066
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0058
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0045
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0037
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0117: 0s -
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0067
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0043
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0030
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0027
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0025
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0020
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0031
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0074
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0062
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0029
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0027
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0031
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0027
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0032
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0041
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0034
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0017
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0017
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0013
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0021
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0014
# 171/171 [==============================] - 2s 12ms/step - loss: 9.7875e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0011
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0010
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0013
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0015
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0023
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0019
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0015
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0021
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0017
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0017
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0014
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0019
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0016
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0013
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0014
# 171/171 [==============================] - 2s 11ms/step - loss: 9.7093e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0143
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0089
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0031
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0012
# 171/171 [==============================] - 2s 11ms/step - loss: 5.8189e-04
# 171/171 [==============================] - 2s 11ms/step - loss: 3.8040e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 2.6608e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 2.3628e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 2.2184e-04
# 171/171 [==============================] - 2s 11ms/step - loss: 2.8676e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 3.4445e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 4.5149e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 6.2562e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 7.1809e-04
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0024
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0042
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0077
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0033
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0018
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0013
# 171/171 [==============================] - 2s 12ms/step - loss: 6.0744e-04
# 171/171 [==============================] - 2s 11ms/step - loss: 4.0611e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 2.3815e-04
# 171/171 [==============================] - 2s 11ms/step - loss: 1.9377e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 1.4669e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 1.6656e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 1.9908e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 2.9564e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 7.3839e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0012
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0092
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0026
# 171/171 [==============================] - 2s 11ms/step - loss: 9.0111e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 4.4170e-04
# 171/171 [==============================] - 2s 11ms/step - loss: 3.5449e-04
# 171/171 [==============================] - 2s 11ms/step - loss: 3.1262e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 3.4266e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0017
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0083
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0066
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0068
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0020
# 171/171 [==============================] - 2s 12ms/step - loss: 9.3878e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 4.6050e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 2.3192e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 1.4242e-04
# 171/171 [==============================] - 2s 11ms/step - loss: 9.9072e-05
# 171/171 [==============================] - 2s 11ms/step - loss: 7.6857e-05
# 171/171 [==============================] - 2s 12ms/step - loss: 5.9679e-05
# 171/171 [==============================] - 2s 11ms/step - loss: 4.9613e-05
# 171/171 [==============================] - 2s 12ms/step - loss: 4.4499e-05
# 171/171 [==============================] - 2s 12ms/step - loss: 8.4332e-05
# 171/171 [==============================] - 2s 12ms/step - loss: 1.4364e-04
# 171/171 [==============================] - 2s 13ms/step - loss: 2.0276e-04
# 171/171 [==============================] - 2s 13ms/step - loss: 3.4076e-04: 0s
# 171/171 [==============================] - 2s 12ms/step - loss: 6.2147e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0020
# 171/171 [==============================] - 2s 13ms/step - loss: 0.0046
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0066
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0031
# 171/171 [==============================] - 2s 12ms/step - loss: 8.4684e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 4.8689e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 3.1688e-04
# 171/171 [==============================] - 2s 13ms/step - loss: 1.7265e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 1.4276e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 9.1074e-05
# 171/171 [==============================] - 2s 12ms/step - loss: 8.0382e-05
# 171/171 [==============================] - 2s 12ms/step - loss: 7.0064e-05
# 171/171 [==============================] - 2s 12ms/step - loss: 7.3413e-05
# 171/171 [==============================] - 2s 12ms/step - loss: 1.3937e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 2.4735e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 6.3130e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 9.9112e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0012
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0013
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0011
# 171/171 [==============================] - 2s 13ms/step - loss: 8.5188e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0015
# 171/171 [==============================] - 2s 12ms/step - loss: 9.4520e-04
# 171/171 [==============================] - 2s 13ms/step - loss: 3.9075e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 3.7234e-04
# 171/171 [==============================] - 2s 13ms/step - loss: 5.6593e-04
# 171/171 [==============================] - 2s 13ms/step - loss: 4.3971e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 6.5904e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 5.4152e-04
# 171/171 [==============================] - 2s 13ms/step - loss: 7.9617e-04
# 171/171 [==============================] - 2s 13ms/step - loss: 0.0046
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0052
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0020
# 171/171 [==============================] - 2s 12ms/step - loss: 8.3502e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0021
# 171/171 [==============================] - 2s 13ms/step - loss: 7.3495e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 8.0513e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 3.3787e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 1.5320e-04
# 171/171 [==============================] - 2s 11ms/step - loss: 8.6616e-05
# 171/171 [==============================] - 2s 11ms/step - loss: 6.5328e-05
# 171/171 [==============================] - 2s 11ms/step - loss: 5.0628e-05
# 171/171 [==============================] - 2s 11ms/step - loss: 3.7110e-05
# 171/171 [==============================] - 2s 12ms/step - loss: 3.0787e-05
# 171/171 [==============================] - 2s 12ms/step - loss: 4.2534e-05
# 171/171 [==============================] - 2s 12ms/step - loss: 5.1123e-05
# 171/171 [==============================] - 2s 11ms/step - loss: 7.7901e-05
# 171/171 [==============================] - 2s 11ms/step - loss: 1.8779e-04
# 171/171 [==============================] - 2s 11ms/step - loss: 3.9746e-04
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0018
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0038
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0030
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0012
# 171/171 [==============================] - 2s 11ms/step - loss: 8.0840e-04
# 171/171 [==============================] - 2s 11ms/step - loss: 6.2825e-04
# 171/171 [==============================] - 2s 11ms/step - loss: 2.6248e-04
# 171/171 [==============================] - 2s 11ms/step - loss: 1.3070e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 1.2942e-04
# 171/171 [==============================] - 2s 11ms/step - loss: 6.9314e-05
# 171/171 [==============================] - 2s 11ms/step - loss: 6.2007e-05
# 171/171 [==============================] - 2s 11ms/step - loss: 5.1935e-05
# 171/171 [==============================] - 2s 11ms/step - loss: 7.0019e-05
# 171/171 [==============================] - 2s 12ms/step - loss: 1.0984e-04
# 171/171 [==============================] - 2s 11ms/step - loss: 1.6287e-04
# 171/171 [==============================] - 2s 11ms/step - loss: 3.9273e-04
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0017
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0020
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0023
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0021
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0040
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0012
# 171/171 [==============================] - 2s 11ms/step - loss: 4.9213e-04
# 171/171 [==============================] - 2s 11ms/step - loss: 2.0635e-04
# 171/171 [==============================] - 2s 11ms/step - loss: 9.5008e-05
# 171/171 [==============================] - 2s 11ms/step - loss: 5.8339e-05
# 171/171 [==============================] - 2s 11ms/step - loss: 3.5629e-05
# 171/171 [==============================] - 2s 11ms/step - loss: 2.5877e-05
# 171/171 [==============================] - 2s 11ms/step - loss: 2.0674e-05
# 171/171 [==============================] - 2s 11ms/step - loss: 1.5067e-05
# 171/171 [==============================] - 2s 11ms/step - loss: 1.2105e-05
# 171/171 [==============================] - 2s 11ms/step - loss: 1.1053e-05
# 171/171 [==============================] - 2s 11ms/step - loss: 1.1595e-05
# 171/171 [==============================] - 2s 11ms/step - loss: 2.4319e-05
# 171/171 [==============================] - 2s 11ms/step - loss: 8.4561e-05
# 171/171 [==============================] - 2s 11ms/step - loss: 5.1021e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0010
# 171/171 [==============================] - 2s 14ms/step - loss: 0.0011
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0016
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0051
# 171/171 [==============================] - 2s 12ms/step - loss: 0.0014
# 171/171 [==============================] - 2s 12ms/step - loss: 7.8564e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 4.7415e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 3.5164e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 2.6826e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 2.0761e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 2.7769e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 2.6491e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 2.0193e-04
# 171/171 [==============================] - 2s 13ms/step - loss: 1.5837e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 1.0984e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 1.2111e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 1.6186e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 2.6661e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 3.0349e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 3.3907e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 4.5675e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 6.4580e-04
# 171/171 [==============================] - 2s 13ms/step - loss: 7.4264e-04
# 171/171 [==============================] - 2s 13ms/step - loss: 6.9698e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 4.4197e-04
# 171/171 [==============================] - 2s 12ms/step - loss: 6.0501e-04
# 171/171 [==============================] - 2s 11ms/step - loss: 7.7757e-04
# 171/171 [==============================] - 2s 11ms/step - loss: 5.3404e-04
# 171/171 [==============================] - 2s 11ms/step - loss: 5.7523e-04
# 171/171 [==============================] - 2s 11ms/step - loss: 7.6558e-04
# 171/171 [==============================] - 2s 11ms/step - loss: 0.0011
# 171/171 [==============================] - 2s 11ms/step - loss: 4.4052e-04
#
# Hora de Término = 00:02:36
# Tempo gasto: 625.0512397289276 segundos

# %%
#trainX

# %%
#trainY

# %%
# Salvando a rede inteira no formato HDF5 (salvando todos os componentes da rede, incluindo os pesos)
model.save(os.path.join(save_path,"RNN02_PipaMainframe_LSTM_Stacked.h5"))

# %% [markdown]
# ## Agora recarregamos o modelo para realizamos uma previsão.

# %%
# Carrega os dados
datasetfull = carrega_dados()

# Split em treino e teste
dataset, test = split_train_test(datasetfull)

dataset = scaler.fit_transform(dataset)

# Split em treino e validação
train, valid = split_train_test_valid(dataset)

# %%
# Reshape em X=t e Y=t+1
trainX, trainY = create_dataset(train, look_back)
validX, validY = create_dataset(valid, look_back)

# Reshape do input para: [samples, time steps, features]
# Time steps
trainX = numpy.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
validX = numpy.reshape(validX, (validX.shape[0], validX.shape[1], 1))

# %%
#carrega o modelo
model = load_model(os.path.join(save_path,"RNN02_PipaMainframe_LSTM_Stacked.h5"))

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_15 (LSTM)               (1, 10, 100)              40800
# _________________________________________________________________
# lstm_16 (LSTM)               (1, 10, 50)               30200
# _________________________________________________________________
# lstm_17 (LSTM)               (1, 20)                   5680
# _________________________________________________________________
# dense_12 (Dense)             (1, 10)                   210
# _________________________________________________________________
# dense_13 (Dense)             (1, 5)                    55
# _________________________________________________________________
# dense_14 (Dense)             (1, 1)                    6
# =================================================================
# Total params: 76,951
# Trainable params: 76,951
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Previsões
batch_size = 1
trainPredict = model.predict(trainX, batch_size = batch_size)
model.reset_states()
validPredict = model.predict(validX, batch_size = batch_size)

# %%
# Inverte as previsões por conta da normalização
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
validPredict = scaler.inverse_transform(validPredict)
validY = scaler.inverse_transform([validY])

# %%
# Calcula o RMSE
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Score em Treino: %.4f RMSE' % (trainScore))
validScore = math.sqrt(mean_squared_error(validY[0], validPredict[:,0]))
print('Score em Validação: %.4f RMSE' % (validScore))
# Out:
# Score em Treino: 6.5300 RMSE
# Score em Validação: 68.6392 RMSE

# %%
# Calcula o RMSE
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Score em Treino: %.4f RMSE' % (trainScore))
validScore = math.sqrt(mean_squared_error(validY[0], validPredict[:,0]))
print('Score em Validação: %.4f RMSE' % (validScore))
# Out:
# Score em Treino: 58.7805 RMSE
# Score em Validação: 71.4025 RMSE

# %%
# Ajusta as previsões em treino para o plot
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# Ajusta as previsões em validação para o plot
validPredictPlot = numpy.empty_like(dataset)
validPredictPlot[:, :] = numpy.nan
validPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = validPredict

# Plot do baseline e previsões
plt.figure(figsize = (20, 8))
plt.title("Previsão com os dados de Validação usando LSTM Stacked") 
plt.plot(scaler.inverse_transform(dataset), label = 'Dados', color = 'green')
plt.plot(trainPredictPlot, color = 'blue', label = 'Treino')
plt.plot(validPredictPlot, color = 'red', label = 'Previsão')
plt.legend(loc = 'upper left') 
plt.show()

# %%
# Ajusta as previsões em treino para o plot
trainPredictPlot = numpy.empty_like(dataset)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# Ajusta as previsões em validação para o plot
validPredictPlot = numpy.empty_like(dataset)
validPredictPlot[:, :] = numpy.nan
validPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = validPredict

# Plot do baseline e previsões
plt.figure(figsize = (20, 8))
plt.title("Previsão com os dados de Validação usando LSTM Stacked") 
plt.plot(scaler.inverse_transform(dataset), label = 'Dados', color = 'green')
plt.plot(trainPredictPlot, color = 'blue', label = 'Treino')
plt.plot(validPredictPlot, color = 'red', label = 'Previsão')
plt.legend(loc = 'upper left') 
plt.show()

# %%
# Plot do baseline e previsões
plt.figure(figsize = (20, 8))
plt.title("Previsão com os dados de Validação LSTM Stacked") 
plt.plot(validY[0], label = 'Dados', color = 'green') 
plt.plot(validPredict[:,0], label = 'Previsão', color = 'red') 
plt.legend(loc = 'best') 
plt.show()

# %% [markdown]
# <a id='etapa4'></a>
# ## Etapa 4: Testar o Modelo

# %% [markdown]
# ## Vamos fazer o Forecasting para os dados de teste.

# %%
# Carrega os dataframe

datasetfull = dataframe.copy()

filtro1 = datasetfull['Broker']=='ETB170'
filtro2 = datasetfull['Service_name']=='PORTALDETRAN'
filtro3 = datasetfull['Programa']=='NSDGX500'
datasetfull = datasetfull[filtro1 & filtro2 & filtro3]

datasetfull = datasetfull.rename_axis('index').reset_index()
datasetfull.drop(columns=['index','Broker','Service_name','Service_class','Programa'], inplace=True)

# Remove as linhas com as datas duplicadas
# Vamos transformar a coluna de data no índice do conjunto de dados. Isso vai facilitar nosso trabalho mais a frente.
# inclui dados missing com a interpolação 

datasetfull.drop_duplicates(subset='Data', inplace=True)
datasetfull = datasetfull.set_index('Data')
datasetfull = datasetfull.resample('D').interpolate()

# Refinamos os dados para o gráfico da série original
# A variável Quantidade é nossa variável target 
target = datasetfull['Quantidade']
raw_values = target.values

datasetfull = datasetfull.values
datasetfull = datasetfull.astype('float32')

# Split em treino e teste
train_size = int(len(datasetfull) * 0.75)
test_size = len(datasetfull) - train_size
dataset, test = datasetfull[0:train_size,:], datasetfull[train_size:len(datasetfull),:]

# Normaliza os dados
scaler = MinMaxScaler(feature_range = (0, 1))
dataset = scaler.fit_transform(dataset)

# Normaliza os dados de Teste
scalerTeste = MinMaxScaler(feature_range = (0, 1))
testScaler = scalerTeste.fit_transform(test)

# Split em treino e validação
train_size = int(len(dataset) * 0.67)
valid_size = len(dataset) - train_size
train, valid = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# Reshape em X=t e Y=t+1
trainX, trainY = create_dataset(train, look_back)
validX, validY = create_dataset(valid, look_back)
testX, testY = create_dataset(testScaler, look_back)

# Reshape do input para: [samples, time steps, features]
# Time steps
trainX = numpy.reshape(trainX, (trainX.shape[0], trainX.shape[1], 1))
validX = numpy.reshape(validX, (validX.shape[0], validX.shape[1], 1))
testX = numpy.reshape(testX, (testX.shape[0], testX.shape[1], 1))

# %%
#carrega o modelo
model = load_model(os.path.join(save_path,"RNN02_PipaMainframe_LSTM_Stacked.h5"))

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_15 (LSTM)               (1, 10, 100)              40800
# _________________________________________________________________
# lstm_16 (LSTM)               (1, 10, 50)               30200
# _________________________________________________________________
# lstm_17 (LSTM)               (1, 20)                   5680
# _________________________________________________________________
# dense_12 (Dense)             (1, 10)                   210
# _________________________________________________________________
# dense_13 (Dense)             (1, 5)                    55
# _________________________________________________________________
# dense_14 (Dense)             (1, 1)                    6
# =================================================================
# Total params: 76,951
# Trainable params: 76,951
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Previsões com dados de Teste
#model.reset_states()
trainPredict = model.predict(trainX, batch_size = batch_size)
model.reset_states()
validPredict = model.predict(validX, batch_size = batch_size)
model.reset_states()
testPredict = model.predict(testX, batch_size = batch_size)

# %%
# Inverte as previsões por conta da normalização
trainPredict = scaler.inverse_transform(trainPredict)
trainY = scaler.inverse_transform([trainY])
validPredict = scaler.inverse_transform(validPredict)
validY = scaler.inverse_transform([validY])
testPredict = scalerTeste.inverse_transform(testPredict)
testY = scalerTeste.inverse_transform([testY])

# %%
# Calcula o RMSE
trainScore = math.sqrt(mean_squared_error(trainY[0], trainPredict[:,0]))
print('Score em Treino: %.4f RMSE' % (trainScore))
validScore = math.sqrt(mean_squared_error(validY[0], validPredict[:,0]))
print('Score em Validação: %.4f RMSE' % (validScore))
testScore = math.sqrt(mean_squared_error(testY[0], testPredict[:,0]))
print('Score em Teste: %.4f RMSE' % (testScore))
# Out:
# Score em Treino: 6.5300 RMSE
# Score em Validação: 68.6392 RMSE
# Score em Teste: 104.1859 RMSE

# %%
# Plot do baseline e previsões
plt.figure(figsize = (20, 6))
plt.title("Previsão com os dados de Teste usando LSTM Time Steps") 
plt.plot(testY[0], label = 'Dados', color = 'green') 
plt.plot(testPredict[:,0], label = 'Previsão', color = 'purple') 
plt.legend(loc = 'best') 
plt.show()

# %%
# Ajusta as previsões em treino para o plot
trainPredictPlot = numpy.empty_like(datasetfull)
trainPredictPlot[:, :] = numpy.nan
trainPredictPlot[look_back:len(trainPredict)+look_back, :] = trainPredict

# Ajusta as previsões em validação para o plot
validPredictPlot = numpy.empty_like(dataset)
validPredictPlot[:, :] = numpy.nan
validPredictPlot[len(trainPredict)+(look_back*2)+1:len(dataset)-1, :] = validPredict               

# Ajusta as previsões em validação para o plot
testPredictPlot = numpy.empty_like(datasetfull)
testPredictPlot[:, :] = numpy.nan
#testPredictPlot[len(testPredict)+(look_back*2)+1:len(datasetfull)-1, :] = testPredict
testPredictPlot[(len(trainPredict) + len(validPredict))+(look_back*3)+2:len(datasetfull)-1, :] = testPredict

# Plot do baseline e previsões
plt.figure(figsize = (20, 6))
plt.title("Previsão com os dados de Treino e Validação usando LSTM Stacked") 
plt.plot(datasetfull, label = 'Dados',color = 'green')
plt.plot(trainPredictPlot, label = 'Treino', color = 'blue')
plt.plot(validPredictPlot, label = 'Validação', color = 'red')
plt.plot(testPredictPlot, label = 'Teste', color = 'purple')
plt.legend(loc = 'upper left') 
plt.show()

# %% [markdown]
# <a id='etapa5'></a>
# ## Etapa 5: Realizar as Previsões

# %% [markdown]
# ## Vamos fazer o Forecasting para 82 dias de horizonte de previsão

# %%
# Carrega os dataframe

datasetfull = dataframe.copy()

filtro1 = datasetfull['Broker']=='ETB170'
filtro2 = datasetfull['Service_name']=='PORTALDETRAN'
filtro3 = datasetfull['Programa']=='NSDGX500'
datasetfull = datasetfull[filtro1 & filtro2 & filtro3]

datasetfull = datasetfull.rename_axis('index').reset_index()
datasetfull.drop(columns=['index','Broker','Service_name','Service_class','Programa'], inplace=True)

# Remove as linhas com as datas duplicadas
# Vamos transformar a coluna de data no índice do conjunto de dados. Isso vai facilitar nosso trabalho mais a frente.
# inclui dados missing com a interpolação 

datasetfull.drop_duplicates(subset='Data', inplace=True)
datasetfull = datasetfull.set_index('Data')
datasetfull = datasetfull.resample('D').interpolate()

# Refinamos os dados para o gráfico da série original
# A variável Quantidade é nossa variável target 
target = datasetfull['Quantidade']
raw_values = target.values

datasetfull = datasetfull.values
datasetfull = datasetfull.astype('float32')

# Split em treino e teste
train_size = int(len(datasetfull) * 0.75)
test_size = len(datasetfull) - train_size
dataset, test = datasetfull[0:train_size,:], datasetfull[train_size:len(datasetfull),:]

# Normaliza os dados
scaler = MinMaxScaler(feature_range = (0, 1))
dataset = scaler.fit_transform(dataset)

# Normaliza os dados de Teste
scalerTeste = MinMaxScaler(feature_range = (0, 1))
testScaler = scalerTeste.fit_transform(test)

# Split em treino e validação
train_size = int(len(dataset) * 0.67)
valid_size = len(dataset) - train_size
train, valid = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# Reshape em X=t e Y=t+1
trainX1, trainY = create_dataset(train, look_back)
validX1, validY = create_dataset(valid, look_back)
testX1, testY = create_dataset(testScaler, look_back)

# Reshape do input para: [samples, time steps, features]
# Time steps
trainX = numpy.reshape(trainX1, (trainX1.shape[0], trainX1.shape[1], 1))
validX = numpy.reshape(validX1, (validX1.shape[0], validX1.shape[1], 1))
testX = numpy.reshape(testX1, (testX1.shape[0], testX1.shape[1], 1))

# %%
#carrega o modelo
model = load_model(os.path.join(save_path,"RNN02_PipaMainframe_LSTM_Stacked.h5"))

model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_15 (LSTM)               (1, 10, 100)              40800
# _________________________________________________________________
# lstm_16 (LSTM)               (1, 10, 50)               30200
# _________________________________________________________________
# lstm_17 (LSTM)               (1, 20)                   5680
# _________________________________________________________________
# dense_12 (Dense)             (1, 10)                   210
# _________________________________________________________________
# dense_13 (Dense)             (1, 5)                    55
# _________________________________________________________________
# dense_14 (Dense)             (1, 1)                    6
# =================================================================
# Total params: 76,951
# Trainable params: 76,951
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fazemos uma previsão em uma etapa
def forecast_lstm(model, X):
    X = X.reshape(1, look_back, 1)
    yhat = model.predict(X)
    yhat1 = scaler.inverse_transform(yhat)
    return yhat1[0,0]

# %%
# Validação direta nos dados de teste

# Lista para as previsões
previsoes_lstm = list()

# Previsões

for i in range(len(testX1)):   
   
    # Ajusta o shape dos dados de teste
    X, y = testX1[i], testY[i]
    
    # Previsão

    yhat = forecast_lstm(model, X)
    
    # Armazena o forecast
    previsoes_lstm.append(yhat)
    expected = raw_values[len(testX1) + i ]
    
    print('Mês = %d, Valor Previsto = %f, Valor Esperado = %f' % (i + 1, yhat, expected))
# Out:
# Mês = 1, Valor Previsto = 70.814163, Valor Esperado = 96.000000
# Mês = 2, Valor Previsto = 108.101601, Valor Esperado = 51.000000
# Mês = 3, Valor Previsto = 47.099873, Valor Esperado = 6.000000
# Mês = 4, Valor Previsto = 52.978165, Valor Esperado = 152.000000
# Mês = 5, Valor Previsto = 144.310562, Valor Esperado = 13.000000
# Mês = 6, Valor Previsto = 100.722389, Valor Esperado = 19.000000
# Mês = 7, Valor Previsto = 16.012545, Valor Esperado = 107.000000
# Mês = 8, Valor Previsto = 90.251488, Valor Esperado = 91.000000
# Mês = 9, Valor Previsto = 106.918938, Valor Esperado = 81.500000
# Mês = 10, Valor Previsto = 44.434444, Valor Esperado = 72.000000
# Mês = 11, Valor Previsto = 108.102959, Valor Esperado = 126.000000
# Mês = 12, Valor Previsto = 138.244293, Valor Esperado = 147.000000
# Mês = 13, Valor Previsto = 112.607903, Valor Esperado = 164.000000
# Mês = 14, Valor Previsto = 20.290304, Valor Esperado = 62.000000
# Mês = 15, Valor Previsto = 127.616333, Valor Esperado = 8.000000
# Mês = 16, Valor Previsto = 76.740700, Valor Esperado = 6.500000
# Mês = 17, Valor Previsto = 60.773346, Valor Esperado = 5.000000
# Mês = 18, Valor Previsto = 116.726173, Valor Esperado = 119.000000
# Mês = 19, Valor Previsto = 139.333420, Valor Esperado = 26.000000
# Mês = 20, Valor Previsto = 130.666977, Valor Esperado = 74.000000
# Mês = 21, Valor Previsto = 119.814117, Valor Esperado = 121.000000
# Mês = 22, Valor Previsto = 148.629532, Valor Esperado = 76.000000
# Mês = 23, Valor Previsto = 121.780380, Valor Esperado = 114.000000
# Mês = 24, Valor Previsto = 99.535706, Valor Esperado = 152.000000
# Mês = 25, Valor Previsto = 12.151089, Valor Esperado = 92.000000
# Mês = 26, Valor Previsto = 74.213036, Valor Esperado = 87.000000
# Mês = 27, Valor Previsto = 128.613541, Valor Esperado = 11.000000
# Mês = 28, Valor Previsto = 143.491486, Valor Esperado = 127.000000
# Mês = 29, Valor Previsto = 16.224566, Valor Esperado = 9.000000
# Mês = 30, Valor Previsto = 74.975746, Valor Esperado = 6.500000
# Mês = 31, Valor Previsto = 104.808525, Valor Esperado = 4.000000
# Mês = 32, Valor Previsto = 85.526520, Valor Esperado = 9.000000
# Mês = 33, Valor Previsto = 45.958420, Valor Esperado = 25.000000
# Mês = 34, Valor Previsto = 115.855255, Valor Esperado = 43.000000
# Mês = 35, Valor Previsto = 73.796394, Valor Esperado = 30.000000
# Mês = 36, Valor Previsto = 18.210300, Valor Esperado = 43.000000
# Mês = 37, Valor Previsto = 132.785019, Valor Esperado = 118.000000
# Mês = 38, Valor Previsto = 82.311150, Valor Esperado = 193.000000
# Mês = 39, Valor Previsto = 59.737957, Valor Esperado = 227.000000
# Mês = 40, Valor Previsto = 50.053982, Valor Esperado = 137.000000
# Mês = 41, Valor Previsto = 87.842888, Valor Esperado = 7.000000
# Mês = 42, Valor Previsto = 150.639572, Valor Esperado = 53.000000
# Mês = 43, Valor Previsto = 52.359634, Valor Esperado = 25.000000
# Mês = 44, Valor Previsto = 146.407288, Valor Esperado = 18.000000
# Mês = 45, Valor Previsto = 34.439892, Valor Esperado = 11.000000
# Mês = 46, Valor Previsto = 131.085297, Valor Esperado = 27.000000
# Mês = 47, Valor Previsto = 122.768379, Valor Esperado = 43.000000
# Mês = 48, Valor Previsto = 169.972855, Valor Esperado = 15.000000
# Mês = 49, Valor Previsto = 133.796951, Valor Esperado = 116.000000
# Mês = 50, Valor Previsto = 137.072372, Valor Esperado = 17.000000
# Mês = 51, Valor Previsto = 110.375359, Valor Esperado = 53.500000
# Mês = 52, Valor Previsto = 55.600925, Valor Esperado = 90.000000
# Mês = 53, Valor Previsto = 57.685585, Valor Esperado = 141.000000
# Mês = 54, Valor Previsto = 91.771095, Valor Esperado = 186.000000
# Mês = 55, Valor Previsto = 61.165405, Valor Esperado = 166.000000
# Mês = 56, Valor Previsto = 121.063156, Valor Esperado = 14.000000
# Mês = 57, Valor Previsto = 33.203098, Valor Esperado = 89.000000
# Mês = 58, Valor Previsto = 108.489510, Valor Esperado = 132.500000
# Mês = 59, Valor Previsto = 125.782036, Valor Esperado = 176.000000
# Mês = 60, Valor Previsto = 84.763374, Valor Esperado = 191.000000
# Mês = 61, Valor Previsto = 28.005968, Valor Esperado = 167.000000
# Mês = 62, Valor Previsto = 49.009396, Valor Esperado = 46.000000
# Mês = 63, Valor Previsto = 35.841545, Valor Esperado = 9.000000
# Mês = 64, Valor Previsto = 34.769150, Valor Esperado = 118.000000
# Mês = 65, Valor Previsto = 18.964600, Valor Esperado = 63.500000
# Mês = 66, Valor Previsto = 132.740799, Valor Esperado = 9.000000
# Mês = 67, Valor Previsto = 70.313461, Valor Esperado = 171.000000
# Mês = 68, Valor Previsto = 7.558936, Valor Esperado = 99.000000
# Mês = 69, Valor Previsto = 36.181934, Valor Esperado = 153.000000
# Mês = 70, Valor Previsto = 153.142471, Valor Esperado = 65.000000
# Mês = 71, Valor Previsto = 93.027870, Valor Esperado = 20.000000
# Mês = 72, Valor Previsto = 5.015007, Valor Esperado = 13.500000
# Mês = 73, Valor Previsto = 25.440645, Valor Esperado = 7.000000
# Mês = 74, Valor Previsto = 66.437149, Valor Esperado = 114.000000
# Mês = 75, Valor Previsto = 39.172943, Valor Esperado = 41.000000
# Mês = 76, Valor Previsto = 111.629845, Valor Esperado = 90.000000
# Mês = 77, Valor Previsto = 95.354263, Valor Esperado = 72.000000
# Mês = 78, Valor Previsto = 54.798367, Valor Esperado = 108.000000
# Mês = 79, Valor Previsto = 125.373817, Valor Esperado = 114.000000
# Mês = 80, Valor Previsto = 110.775612, Valor Esperado = 120.000000
# Mês = 81, Valor Previsto = 84.999107, Valor Esperado = 167.000000

# %%
previsoes_lstm
# Out:
# [70.81416,
#  108.1016,
#  47.099873,
#  52.978165,
#  144.31056,
#  100.72239,
#  16.012545,
#  90.25149,
#  106.91894,
#  44.434444,
#  108.10296,
#  138.2443,
#  112.6079,
#  20.290304,
#  127.61633,
#  76.7407,
#  60.773346,
#  116.72617,
#  139.33342,
#  130.66698,
#  119.81412,
#  148.62953,
#  121.78038,
#  99.535706,
#  12.151089,
#  74.213036,
#  128.61354,
#  143.49149,
#  16.224566,
#  74.975746,
#  104.808525,
#  85.52652,
#  45.95842,
#  115.855255,
#  73.796394,
#  18.2103,
#  132.78502,
#  82.31115,
#  59.737957,
#  50.05398,
#  87.84289,
#  150.63957,
#  52.359634,
#  146.40729,
#  34.43989,
#  131.0853,
#  122.76838,
#  169.97285,
#  133.79695,
#  137.07237,
#  110.37536,
#  55.600925,
#  57.685585,
#  91.771095,
#  61.165405,
#  121.063156,
#  33.2031,
#  108.48951,
#  125.782036,
#  84.763374,
#  28.005968,
#  49.009396,
#  35.841545,
#  34.76915,
#  18.9646,
#  132.7408,
#  70.31346,
#  7.5589356,
#  36.181934,
#  153.14247,
#  93.02787,
#  5.0150065,
#  25.440645,
#  66.43715,
#  39.172943,
#  111.629845,
#  95.35426,
#  54.798367,
#  125.37382,
#  110.77561,
#  84.99911]

# %%
# Última data da série
target.index[-1]
# Out:
# Timestamp('2022-10-25 00:00:00', freq='D')

# %%
# Cria sequência de datas a partir da última data da nossa série original
datas_para_prever_forecasting = [target.index[-1] + DateOffset(days = x) for x in range(0, 82)]

# %%
# Objetos do tipo pd.Series dão mais trabalho para manipular. Vamos converter a série original em dataframe.
df_original = pd.DataFrame(target)

# %%
# Vamos agora criar um novo dataframe 
# O índice (data) será a sequência de datas futuras
# O nome da coluna de dados extraímos da série original
# ATENÇÃO: Não estamos extraindo os dados da série original, somente o nome da coluna
data_futuras = pd.DataFrame(index = datas_para_prever_forecasting[1:], columns = df_original.columns)

# %%
# Visualiza os dados
# Entendeu por que os valores NaN? São datas futuras, e precisamos agora incluir nossas previsões.
data_futuras
# Out:
#            Quantidade
# 2022-10-26        NaN
# 2022-10-27        NaN
# 2022-10-28        NaN
# 2022-10-29        NaN
# 2022-10-30        NaN
# ...               ...
# 2023-01-10        NaN
# 2023-01-11        NaN
# 2023-01-12        NaN
# 2023-01-13        NaN
# 2023-01-14        NaN
#
# [81 rows x 1 columns]

# %%
# Usamos as datas futuras para extrair as previsões do nosso modelo
df_predict = pd.DataFrame(testPredict,
                          index = data_futuras.index, columns = ['Prediction'])

# %%
df_predict
# Out:
#             Prediction
# 2022-10-26   79.064041
# 2022-10-27  118.138428
# 2022-10-28   54.213284
# 2022-10-29   60.373287
# 2022-10-30  156.082642
# ...                ...
# 2023-01-10  104.780190
# 2023-01-11   62.280716
# 2023-01-12  136.238373
# 2023-01-13  120.940582
# 2023-01-14   93.928780
#
# [81 rows x 1 columns]

# %%
# Concatenamos a série original com os valores de forecasting de 12 meses além da série
df_forecasting = pd.concat([df_original, df_predict], axis = 1)

# %%
# Visualiza o dataframe
df_forecasting
# Out:
#             Quantidade  Prediction
# 2021-10-26       162.0         NaN
# 2021-10-27        66.0         NaN
# 2021-10-28        58.0         NaN
# 2021-10-29        44.0         NaN
# 2021-10-30        83.0         NaN
# ...                ...         ...
# 2023-01-10         NaN  104.780190
# 2023-01-11         NaN   62.280716
# 2023-01-12         NaN  136.238373
# 2023-01-13         NaN  120.940582
# 2023-01-14         NaN   93.928780
#
# [446 rows x 2 columns]

# %%
df_forecasting.to_csv(r'./CSV/PipaMainframe_Forecasting_Stacked.csv', index = False)

# %%
# Plot
plt.figure(figsize = (18, 6))

# Série original
plt.plot(target.index[0:272], target.values[0:272], label = 'Valores Observados', color = 'Blue')
plt.plot(target.index[272:], target.values[272:], label = 'Dados de Teste', color = 'green')

# Previsões
plt.plot(df_forecasting.index, df_forecasting['Prediction'], label = 'Forecasting',  color = 'Red')

plt.title('Forecasting Com Modelo LSTM Sem_early stoppProfundo Em Horizonte de 82 dias de Previsão')
plt.xlabel('Data')
plt.ylabel('Distanciamento Social')
plt.legend()
plt.show()

# %% [markdown]
# # Fim
